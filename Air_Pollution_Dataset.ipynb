# %% [markdown]
# # **Air Polution dataset for India and Nepal**
#
# *October 27, 2024*
#
# ![dataset-cover.png](data:image/png;base64,...)

# %% [markdown]
# The **Air Pollution Dataset** used for this analysis is sourced from Kaggle, a popular platform for datasets and data science projects. The data has the following variables:
# * index
# * Location
# * Filename
# * Year
# * Month
# * Day
# * Hour
# * AQI
# * PM2.5
# * PM10
# * O3
# * CO
# * SO2
# * NO2
# * AQI_Class

# %% [markdown]
# ## **Reading the Air Pollution Dataset**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## **Data Preparation and Cleaning**

# %%
# Importing the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset_path = '/content/drive/MyDrive/Air_Pollution_Image_Dataset/Air_Pollution_Image_Dataset/Air_Pollution_Image_Dataset/Combined_Dataset/IND_and_Nep_AQI_Dataset.csv'

# %%
# Loading the dataset into a data frame
df = pd.read_csv(dataset_path)

# %%
df.head(10)
# Out:
#             Location                         Filename  Year  Month  Day  \
# 0  Biratnagar, Nepal   BRI_Un_2023-02-02- 12.00-9.jpg  2023      2    2
# 1  Biratnagar, Nepal   BRI_Un_2023-02-02- 12.00-8.jpg  2023      2    2
# 2  Biratnagar, Nepal   BRI_Un_2023-02-02- 12.00-7.jpg  2023      2    2
# 3  Biratnagar, Nepal   BRI_Un_2023-02-02- 12.00-6.jpg  2023      2    2
# 4  Biratnagar, Nepal   BRI_Un_2023-02-02- 12.00-5.jpg  2023      2    2
# 5  Biratnagar, Nepal   BRI_Un_2023-02-02- 12.00-4.jpg  2023      2    2
# 6  Biratnagar, Nepal   BRI_Un_2023-02-02- 12.00-3.jpg  2023      2    2
# 7  Biratnagar, Nepal   BRI_Un_2023-02-02- 12.00-2.jpg  2023      2    2
# 8  Biratnagar, Nepal  BRI_Un_2023-02-02- 12.00-18.jpg  2023      2    2
# 9  Biratnagar, Nepal  BRI_Un_2023-02-02- 12.00-17.jpg  2023      2    2
#
#     Hour  AQI  PM2.5    PM10     O3    CO  SO2   NO2    AQI_Class
# 0  12:00  158  70.08  100.82  58.89  0.49  4.4  1.04  d_Unhealthy
# ...

# %%
 # Checking for missing values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12240 entries, 0 to 12239
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Location   12240 non-null  object
#  1   Filename   12240 non-null  object
#  2   Year       12240 non-null  int64
#  3   Month      12240 non-null  int64
#  4   Day        12240 non-null  int64
#  5   Hour       12240 non-null  object
#  6   AQI        12240 non-null  int64
#  7   PM2.5      12240 non-null  float64
#  8   PM10       12240 non-null  float64
#  9   O3         11938 non-null  float64
#  10  CO         11660 non-null  float64
#  11  SO2        10757 non-null  float64
#  12  NO2        11800 non-null  float64
#  13  AQI_Class  12240 non-null  object
# dtypes: float64(6), int64(4), object(4)
# memory usage: 1.3+ MB

# %%
# Number of rows and columns
df.shape
# Out:
# (12240, 14)

# %%
# Checking Descriptive statistics
df.describe()
# Out:
#                Year         Month           Day           AQI         PM2.5  \
# count  12240.000000  12240.000000  12240.000000  12240.000000  12240.000000
# mean    2022.947631      2.686111     12.114706    167.626797    142.999267
# std        0.222780      1.774345      8.269053    102.818213    130.745815
# min     2022.000000      2.000000      1.000000     15.000000      4.000000
# 25%     2023.000000      2.000000      3.000000     97.000000     35.000000
# 50%     2023.000000      2.000000     13.000000    152.000000     70.080000
# 75%     2023.000000      3.000000     20.000000    230.000000    257.000000
# max     2023.000000     10.000000     28.000000    450.000000    500.000000
#
#                PM10            O3            CO           SO2           NO2
# count  12240.000000  11938.000000  11660.000000  10757.000000  11800.000000
# mean     145.663935     39.491436    101.230361     13.239595     37.843576
# ...

# %%
# Display the column names in the dataset
print(df.columns)
# Out:
# Index(['Location', 'Filename', 'Year', 'Month', 'Day', 'Hour', 'AQI', 'PM2.5',
#        'PM10', 'O3', 'CO', 'SO2', 'NO2', 'AQI_Class'],
#       dtype='object')

# %%
# Define bins and labels for categorizing pollutants
aqi_bins = [0, 50, 100, 150, 200, 300, 500]
aqi_labels = ['Good', 'Moderate', 'Unhealthy for Sensitive Groups', 'Unhealthy', 'Very Unhealthy', 'Hazardous']

pm25_bins = [0, 50, 100, 150, 200, 300, 500]
pm25_labels = ['Good', 'Moderate', 'Unhealthy for Sensitive Groups', 'Unhealthy', 'Very Unhealthy', 'Hazardous']

pm10_bins = [0, 50, 100, 150, 200, 300, 500]
pm10_labels = ['Good', 'Moderate', 'Unhealthy for Sensitive Groups', 'Unhealthy', 'Very Unhealthy', 'Hazardous']

o3_bins = [0, 50, 100, 150, 200, 300, 500]
o3_labels = ['Good', 'Moderate', 'Unhealthy for Sensitive Groups', 'Unhealthy', 'Very Unhealthy', 'Hazardous']

co_bins = [0, 1, 2, 10, 17, 34, 50]
co_labels = ['Good', 'Moderate', 'Unhealthy for Sensitive Groups', 'Unhealthy', 'Very Unhealthy', 'Hazardous']

so2_bins = [0, 20, 80, 250, 500, 750, 1000]
so2_labels = ['Good', 'Moderate', 'Unhealthy for Sensitive Groups', 'Unhealthy', 'Very Unhealthy', 'Hazardous']

no2_bins = [0, 40, 80, 180, 280, 400, 500]
no2_labels = ['Good', 'Moderate', 'Unhealthy for Sensitive Groups', 'Unhealthy', 'Very Unhealthy', 'Hazardous']

# Apply categorization
df['AQI_Class'] = pd.cut(df['AQI'], bins=aqi_bins, labels=aqi_labels)
df['PM2.5_Class'] = pd.cut(df['PM2.5'], bins=pm25_bins, labels=pm25_labels)
df['PM10_Class'] = pd.cut(df['PM10'], bins=pm10_bins, labels=pm10_labels)
df['O3_Class'] = pd.cut(df['O3'], bins=o3_bins, labels=o3_labels)
df['CO_Class'] = pd.cut(df['CO'], bins=co_bins, labels=co_labels)
df['SO2_Class'] = pd.cut(df['SO2'], bins=so2_bins, labels=so2_labels)
df['NO2_Class'] = pd.cut(df['NO2'], bins=no2_bins, labels=no2_labels)

# Display value counts for each class
print("AQI Class Counts:")
print(df['AQI_Class'].value_counts())

print("\nPM2.5 Class Counts:")
print(df['PM2.5_Class'].value_counts())

print("\nPM10 Class Counts:")
print(df['PM10_Class'].value_counts())

print("\nO3 Class Counts:")
print(df['O3_Class'].value_counts())

print("\nCO Class Counts:")
print(df['CO_Class'].value_counts())

print("\nSO2 Class Counts:")
print(df['SO2_Class'].value_counts())

print("\nNO2 Class Counts:")
print(df['NO2_Class'].value_counts())
# Out:
# AQI Class Counts:
# AQI_Class
# Unhealthy for Sensitive Groups    2912
# Unhealthy                         2573
# Very Unhealthy                    2194
# Moderate                          1573
# Good                              1541
# Hazardous                         1447
# Name: count, dtype: int64
#
# PM2.5 Class Counts:
# PM2.5_Class
# Good                              3967
# Moderate                          3086
# Hazardous                         2335
# Unhealthy                         1182
# Very Unhealthy                    1133
# Unhealthy for Sensitive Groups     537
# Name: count, dtype: int64
#
# PM10 Class Counts:
# PM10_Class
# Moderate                          3208
# Unhealthy                         2839
# Good                              2153
# Unhealthy for Sensitive Groups    2042
# Hazardous                         1182
# Very Unhealthy                     816
# Name: count, dtype: int64
#
# O3 Class Counts:
# O3_Class
# ...

# %%
# Calculating the range for each pollutant
range_values = {
    "AQI": (df['AQI'].min(), df['AQI'].max()),
    "PM2.5": (df['PM2.5'].min(), df['PM2.5'].max()),
    "PM10": (df['PM10'].min(), df['PM10'].max()),
    "O3": (df['O3'].min(), df['O3'].max()),
    "CO": (df['CO'].min(), df['CO'].max()),
    "SO2": (df['SO2'].min(), df['SO2'].max()),
    "NO2": (df['NO2'].min(), df['NO2'].max())
}

# Displaying the range for each pollutant
print("Range of Values:")
for pollutant, value_range in range_values.items():
    print(f"{pollutant}: {value_range}")
# Out:
# Range of Values:
# AQI: (15, 450)
# PM2.5: (4.0, 500.0)
# PM10: (7.0, 480.0)
# O3: (1.0, 225.0)
# CO: (0.0, 410.0)
# SO2: (2.0, 57.0)
# NO2: (0.67, 169.0)

# %%
# Calculating the range for each pollutant
range_AQI = df['AQI'].max() - df['AQI'].min()
range_PM25 = df['PM2.5'].max() - df['PM2.5'].min()
range_PM10 = df['PM10'].max() - df['PM10'].min()
range_O3 = df['O3'].max() - df['O3'].min()
range_CO = df['CO'].max() - df['CO'].min()
range_SO2 = df['SO2'].max() - df['SO2'].min()
range_NO2 = df['NO2'].max() - df['NO2'].min()

# Displaying the range for each pollutant
print("The range of AQI is {}".format(range_AQI))
print("The range of PM2.5 is {}".format(range_PM25))
print("The range of PM10 is {}".format(range_PM10))
print("The range of O3 is {}".format(range_O3))
print("The range of CO is {}".format(range_CO))
print("The range of SO2 is {}".format(range_SO2))
print("The range of NO2 is {}".format(range_NO2))
# Out:
# The range of AQI is 435
# The range of PM2.5 is 496.0
# The range of PM10 is 473.0
# The range of O3 is 224.0
# The range of CO is 410.0
# The range of SO2 is 55.0
# The range of NO2 is 168.33

# %%
#Find the duplicates
df.duplicated().sum()
# Out:
# 0

# %%
# Checking unique values for each column
unique_values = {col: df[col].unique() for col in df.columns}

# Displaying the unique values for each column
for col, values in unique_values.items():
    print(f"\nUnique values in '{col}':\n{values}")
# Out:
# Unique values in 'Location':
# ['Biratnagar, Nepal' 'Tamil Nadu' 'Mumbai' 'Knowledge park, Greater Noida'
#  'New Ind Town, Faridabad' 'ITO, Delhi' 'Bengaluru' 'Dimapur, Nagaland']
#
# Unique values in 'Filename':
# ['BRI_Un_2023-02-02- 12.00-9.jpg' 'BRI_Un_2023-02-02- 12.00-8.jpg'
#  'BRI_Un_2023-02-02- 12.00-7.jpg' ...
#  'Dimapur_MOD_2023-02-10-08.30-2-9.jpg'
#  'Dimapur_MOD_2023-02-10-08.30-3.jpg' 'Dimapur_MOD_2023-02-10-08.30-4.jpg']
#
# Unique values in 'Year':
# [2023 2022]
#
# Unique values in 'Month':
# [ 2  3 10]
#
# Unique values in 'Day':
# [ 2  3  9 13 14 16 10 20 21 22 23 27 28  1  8  6 11 15 17 18 19 24 25  5
#  12  7  4 26]
#
# Unique values in 'Hour':
# ['12:00' '15:00' '17:00' '10:00' '16:00' '8:00' '9:30' '14:30' '12:30'
#  '9:00' '13:30' '8:30' '16:30' '15:30' '11:30' '13:00' '19:00' '11:00'
#  '18:00' '10:30' '14:00']
#
# Unique values in 'AQI':
# [158 156 163 141 171  91 101 154 107 150 167  78 105  37  43  29  36  73
# ...

# %%
# Finding null values
df.isnull().sum()
# Out:
# Location          0
# Filename          0
# Year              0
# Month             0
# Day               0
# Hour              0
# AQI               0
# PM2.5             0
# PM10              0
# O3              302
# CO              580
# SO2            1483
# NO2             440
# AQI_Class         0
# PM2.5_Class       0
# PM10_Class        0
# O3_Class        302
# CO_Class       7160
# SO2_Class      1483
# NO2_Class       440
# dtype: int64

# %%
# Dropping rows with null values
df.dropna(inplace=True)

# %%
# Checking the changes now
df.isnull().sum()
# Out:
# Location       0
# Filename       0
# Year           0
# Month          0
# Day            0
# Hour           0
# AQI            0
# PM2.5          0
# PM10           0
# O3             0
# CO             0
# SO2            0
# NO2            0
# AQI_Class      0
# PM2.5_Class    0
# PM10_Class     0
# O3_Class       0
# CO_Class       0
# SO2_Class      0
# NO2_Class      0
# dtype: int64

# %%
# Counting number of unique Location
unique_count = df['Location'].nunique()
print(f"Number of unique values in 'Location' column: {unique_count}")
# Out:
# Number of unique values in 'Location' column: 6

# %%
#Datatypes
df.dtypes
# Out:
# Location         object
# Filename         object
# Year              int64
# Month             int64
# Day               int64
# Hour             object
# AQI               int64
# PM2.5           float64
# PM10            float64
# O3              float64
# CO              float64
# SO2             float64
# NO2             float64
# AQI_Class      category
# PM2.5_Class    category
# PM10_Class     category
# O3_Class       category
# CO_Class       category
# SO2_Class      category
# NO2_Class      category
# dtype: object

# %% [markdown]
# ## **Exploratory Analysis and Visualization**

# %%
# Creating a colorful histogram for the distribution of AQI values
plt.figure(figsize=(10, 6))
sns.histplot(df['AQI'], bins=50, kde=True, edgecolor='black')
plt.title('Distribution of AQI Values')
plt.xlabel('AQI')
plt.ylabel('Frequency')
plt.show()

# Defining a custom order for AQI categories
aqi_order = ['Good', 'Moderate', 'Unhealthy for Sensitive Groups', 'Unhealthy', 'Very Unhealthy', 'Severe']

# Creating a colorful bar chart with updated syntax to avoid the FutureWarning
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='AQI_Class', hue='AQI_Class', palette='viridis', order=aqi_order, dodge=False)
plt.legend([],[], frameon=False)
plt.title('Distribution of AQI Categories')
plt.xlabel('AQI Category')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
# Calculating the mean AQI for each location and sorting in descending order
mean_aqi_per_location = df.groupby('Location')['AQI'].mean().sort_values(ascending=False)

# Selecting the top 10 locations with the highest mean AQI values
top_10_locations = mean_aqi_per_location.head(10)

# Filtering the dataset to include only data from the top 10 locations
top_10_data = df[df['Location'].isin(top_10_locations.index)]

# Creating a table to display mean AQI values for the top 10 locations
top_10_table = top_10_locations.reset_index()
top_10_table.columns = ['Location', 'Mean AQI']

# Displaying the table
top_10_table
# Out:
#                         Location    Mean AQI
# 0                     ITO, Delhi  348.875000
# 1  Knowledge park, Greater Noida  213.532764
# 2              Biratnagar, Nepal  139.063105
# 3                     Tamil Nadu  104.345638
# 4                         Mumbai   98.488189
# 5              Dimapur, Nagaland   89.057143

# %%
# Calculating the mean AQI for each location and selecting the top 10
mean_aqi_per_location = df.groupby('Location')['AQI'].mean().sort_values(ascending=False)
top_10_locations = mean_aqi_per_location.head(10)
top_10_table = top_10_locations.reset_index()
top_10_table.columns = ['Location', 'Mean AQI']

# Creating a bar chart to compare mean AQI values across the top 10 locations with updated syntax
plt.figure(figsize=(12, 8))
sns.barplot(data=top_10_table, x='Location', y='Mean AQI', hue='Location', palette='viridis', dodge=False)
plt.legend([],[], frameon=False)
plt.title('Top 10 Locations with Highest Mean AQI Values')
plt.xlabel('Location')
plt.xticks(rotation=45)
plt.ylabel('Mean AQI')
plt.show()

# %%
# Selecting relevant columns for correlation analysis
relevant_columns = ['AQI', 'PM2.5', 'PM10', 'O3', 'CO', 'SO2', 'NO2']
correlation_matrix = df[relevant_columns].corr()

# Creating a heatmap to visualize the correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Matrix of Air Quality Indicators')
plt.show()

# %%
# Selecting relevant columns for the pairplot
relevant_columns = ['AQI', 'PM2.5', 'PM10', 'O3', 'CO', 'SO2', 'NO2']

# Creating a pairplot to visualize pairwise relationships
sns.pairplot(df[relevant_columns], diag_kind='kde', plot_kws={'alpha':0.5})
plt.suptitle('Pairwise Relationships Between Air Quality Metrics', y=1.02)  # Adjust title position
plt.show()

# %%
# Define AQI categories and corresponding ranges
aqi_bins = [0, 50, 100, 150, 200, 300, 500]
aqi_labels = ['Good', 'Moderate', 'Unhealthy for Sensitive Groups', 'Unhealthy', 'Very Unhealthy', 'Severe']

# Create the 'AQI_Category' column
df['AQI_Category'] = pd.cut(df['AQI'], bins=aqi_bins, labels=aqi_labels)

# Creating a colorful box plot for AQI values within each AQI category
plt.figure(figsize=(12, 8))
sns.boxplot(data=df, x='AQI_Category', y='AQI', hue='AQI_Category', palette='Set2', order=aqi_labels, dodge=False)
plt.legend([], [], frameon=False)
plt.title('Distribution of AQI Values within Each AQI Category')
plt.xlabel('AQI Category')
plt.ylabel('AQI Value')
plt.xticks(rotation=45)
plt.show()

# %%
# Calculating the mean values for each pollutant
mean_pollutants = df[['PM2.5', 'PM10', 'O3', 'CO', 'SO2', 'NO2']].mean()

# Calculating pollutant contributions as a percentage of the overall mean AQI
overall_mean_aqi = df['AQI'].mean()
pollutant_contributions = (mean_pollutants / overall_mean_aqi) * 100

# Plotting the pie chart for individual pollutant contributions as a percentage of AQI
plt.figure(figsize=(8, 8))
plt.pie(pollutant_contributions, labels=pollutant_contributions.index, autopct='%1.1f%%', startangle=140)
plt.title('Individual Pollutant Contributions as a Percentage of AQI')
plt.axis('equal')
plt.show()
